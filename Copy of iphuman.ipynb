# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPool2D, Flatten,Input
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers import Conv2D, MaxPooling2D, Embedding, Reshape, Concatenate, Dropout
from keras.layers import ZeroPadding2D

# %%
model = Sequential()

# %%
model.add(Conv2D(300, kernel_size=(3, 3), activation='relu', input_shape=(32,32,1),padding='same'))

# %%
#keras.layers.ZeroPadding2D(padding=(1,1))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Conv2D(250, kernel_size=(3, 3), activation='relu', padding='same'))

# %%
#ZeroPadding2D(padding=(1,1))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Conv2D(200, kernel_size=(3, 3), activation='relu', padding='same'))

# %%
#ZeroPadding2D(padding=(1,1))

# %%
model.add(Conv2D(150, kernel_size=(3, 3), activation='relu', padding='same'))

# %%
#ZeroPadding2D(padding=(1,1))

# %%
model.add(Conv2D(100, kernel_size=(3, 3), activation='relu',padding='same'))

# %%
#ZeroPadding2D(padding=(1,1))

# %%
model.add(Flatten())

# %%
model.add(Dense(500, activation='relu'))

# %%
model.add(Dense(6,activation='tanh'))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/My Drive/colab_data/training_human_32x32.csv')

# %%
df.head()

# %%
df.columns
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'nose_tip_x', 'nose_tip_y', 'image', 'image_gt'],
#       dtype='object')

# %%
y.shape
# Out:
# (8560, 6)

# %%
dataList = []
for index, row in df.iterrows(): 
    mylist = [row.left_eye_center_x, row.left_eye_center_y]
    mylist1 = [row.right_eye_center_x, row.right_eye_center_y]
    mylist2 = [row.nose_tip_x, row.nose_tip_y]
    dataList.append(mylist)
    dataList.append(mylist1)
    dataList.append(mylist2)

# %%
list_leye_x = []
list_leye_y = []
list_reye_x = []
list_reye_y = []
list_nose_x = []
list_nose_y = []
for index, row in df.iterrows():
  list_leye_x.append(row.left_eye_center_x)
  list_leye_y.append(row.left_eye_center_y)
  list_reye_x.append(row.right_eye_center_x)
  list_reye_y.append(row.right_eye_center_y)
  list_nose_x.append(row.nose_tip_x)
  list_nose_y.append(row.nose_tip_y)
tr_leye_x=list_leye_x[1713:]
tr_leye_y=list_leye_y[1713:]
tr_reye_x=list_reye_x[1713:]
tr_reye_y=list_reye_y[1713:]
tr_nose_x=list_nose_x[1713:]
tr_nose_y=list_nose_y[1713:]
ts_leye_x=list_leye_x[0:1713]
ts_leye_y=list_leye_y[0:1713]
ts_reye_x=list_reye_x[0:1713]
ts_reye_y=list_reye_y[0:1713]
ts_nose_x=list_nose_x[0:1713]
ts_nose_y=list_nose_y[0:1713]

# %%
i=0
new_list=[]
while i<len(dataList):
  new_list.append(np.array(dataList[i:i+3]).flatten())
  i+=3

y = np.array(new_list)
print(y.shape)
y_test=y[0:1713]
y_train=y[1713:]
print(y_test.shape)
print(y_train.shape)
# Out:
# (8560, 6)
# (1713, 6)
# (6847, 6)

# %%
Y_train=new_list[1713:]
Y_test=new_list[0:1713]
print(Y_train)
# Out:
# [array([22, 11, 10, 12, 17, 19]), array([22, 12, 10, 12, 16, 18]), array([20, 12,  8, 11, 16, 20]), array([ 15,  29,  16,   3, 253,  21]), array([21, 10,  4, 16, 16, 24]), array([ 18,  20,   4,   2, 255,  17]), array([23, 12,  9, 13, 16, 18]), array([23, 16,  3, 10, 10, 20]), array([21,  8, 10, 23, 24, 22]), array([21, 10, 10, 14, 17, 19]), array([21, 10, 10, 14, 17, 19]), array([17,  5,  8, 19, 20, 18]), array([17, 23, 15,  9,  7, 18]), array([22, 12, 10, 10, 15, 19]), array([22, 12, 10, 10, 15, 19]), array([13, 21, 11,  4,  2, 15]), array([21, 11, 10, 13, 16, 20]), array([22, 11, 11, 12, 18, 18]), array([26, 10,  6, 21, 25, 26]), array([19, 18,  6,  7,  6, 18]), array([21, 12,  9, 13, 15, 18]), array([21, 12,  9, 13, 15, 18]), array([22, 21, 10, 10, 10, 21]), array([17,  4,  7, 20, 27, 16]), array([21, 10,  9, 13, 20, 20]), array([23, 10,  8, 22, 22, 26]), array([19,  8,  5, 15, 18, 19]), array([22, 11, 11, 12, 18, 18]), array([23, 13,  2, 12, 10, 27]), array([21, 11, 10, 11, 16, 1
# ...

# %%
#my__list = df['image'].tolist()

#matrix = []
#for i in my__list:
    #image_rows = []

  #    print(i)    
#one_row = my__list[0]
   
  #mylist  = i.split()
   # while mylist != []:
#image_rows.append([float(Val) for Val in mylist[:32]])
      #    mylist = mylist[32:]
   # matrix.append(image_rows)


#X = np.array(matrix)
#type(X)
#print(X)
print(y_train)
# Out:
# [  4 255  15 ...  12  20  17]

# %%
from keras.preprocessing import image

# %%
X_test = []

for i in range(0,1713):

  Temp_Img=image.load_img('/content/drive/My Drive/colab_data/test_images/' + str(i) + '.jpeg', target_size = (32,32),grayscale=True)
  Temp_Img=image.img_to_array(Temp_Img)
  X_test.append(Temp_Img)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
X_test=np.array(X_test)
#print(X_test)
#type(X_test)

# %%
print (X_test.shape,y_test.shape)
# Out:
# (1713, 32, 32, 1) (1713, 6)

# %%
X_train = []

for j in range(1713,8560):
  
  Train_img=image.load_img('/content/drive/My Drive/colab_data/train_images/' +str(j) + '.jpeg', target_size=(32,32),grayscale=True)
  Train_img=image.img_to_array(Train_img)
  X_train.append(Train_img)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:98: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
X_train=np.array(X_train)

# %%
print(X_train.shape)
# Out:
# (6847, 32, 32, 1)

# %%
#X.shape
y.shape
# Out:
# (8560, 6)

# %%
##################################################################

# %%
import numpy as np
import pandas as pd
#df = pd.read_csv('/content/drive/My Drive/colab_data/training_human_32x32.csv')

# %%
x_train.shape
y_train.shape
# Out:
# (30708,)

# %%
from keras.models import Model,save_model,load_model
from keras.layers import Input

from keras import losses
from keras import optimizers
sgd = optimizers.SGD(lr=0.0003)
#inputs=Input(shape=(224,224,3))
#final=Model(inputs=inputs,outputs=model)
model.compile(loss=losses.mean_squared_error, optimizer=sgd, metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 300)       3000
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 300)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 250)       675250
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 250)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 200)         450200
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 150)         270150
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 100)         135100
# ...

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
Model.fit(X_train, y_train,
          batch_size=128,
          epochs=100,
          verbose=1,
          validation_data=(X_test, y_test))

# %%
# !pip freeze

# %%
#y_train=[[str(Item) for Item in list] for list in y_train]
#y_test=[[str(Item) for Item in list] for list in y_test]
#print(Y_train)

# %%
import os
img_train=os.listdir('/content/drive/My Drive/colab_data/train_images/')
df1=pd.DataFrame(list(zip(sorted(img_train),tr_leye_x,tr_leye_y,tr_reye_x,tr_reye_y,tr_nose_x,tr_nose_x)), columns=['img_train','tr_leyex','tr_leyey','tr_reyex','tr_reyey','tr_nosex','tr_nosey'])
#df1['y_train'].astype('str')
#print(df1)
img_test=os.listdir('/content/drive/My Drive/colab_data/test_images/')
img_test=sorted(img_test, key=lambda x: int(os.path.splitext(x)[0]))
df2=pd.DataFrame(list(zip(img_test, ts_leye_x,ts_leye_y,ts_reye_x,ts_reye_y,ts_nose_x,ts_nose_x)), columns=['img_test','ts_leyex','ts_leyey','ts_reyex','ts_reyey','ts_nosex','ts_nosey'])
#print(df2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-51e5e9a64fd7> in <module>()
#       1 import os
# ----> 2 img_train=os.listdir('/content/drive/My Drive/colab_data/train_images/')
#       3 df1=pd.DataFrame(list(zip(sorted(img_train),tr_leye_x,tr_leye_y,tr_reye_x,tr_reye_y,tr_nose_x,tr_nose_x)), columns=['img_train','tr_leyex','tr_leyey','tr_reyex','tr_reyey','tr_nosex','tr_nosey'])
#       4 #df1['y_train'].astype('str')
#       5 #print(df1)
#
# OSError: [Errno 5] Input/output error: '/content/drive/My Drive/colab_data/train_images/'

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
tr_col=["tr_leyex","tr_leyey","tr_reyex","tr_reyey","tr_nosex","tr_nosey"]
ts_col=["ts_leyex","ts_leyey","ts_reyex","ts_reyey","ts_nosex","ts_nosey"]

# %%
datagen=ImageDataGenerator(rescale=1./255)
train_generator=datagen.flow_from_dataframe(dataframe=df1, directory='/content/drive/My Drive/colab_data/train_images/', x_col="img_train", y_col=tr_col, color_mode="grayscale", class_mode="raw", target_size=(32,32), batch_size=128)
# Out:
# Found 6847 validated image filenames.

# %%
datagen=ImageDataGenerator(rescale=1./255)
test_generator=datagen.flow_from_dataframe(dataframe=df2, directory='/content/drive/My Drive/colab_data/test_images/', x_col="img_test", y_col=ts_col, color_mode="grayscale", class_mode="raw", target_size=(32,32), batch_size=128)
# Out:
# Found 1713 validated image filenames.

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=test_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=50)
model.save('new_model.h5')
# Out:
# Epoch 1/50
# 53/53 [==============================] - 247s 5s/step - loss: 363.6486 - acc: 0.1157 - val_loss: 436.0861 - val_acc: 0.2320
# Epoch 2/50
# 53/53 [==============================] - 242s 5s/step - loss: 350.5257 - acc: 0.4650 - val_loss: 408.4984 - val_acc: 0.5804
# Epoch 3/50
# 53/53 [==============================] - 242s 5s/step - loss: 344.8997 - acc: 0.6246 - val_loss: 419.8418 - val_acc: 0.6240
# Epoch 4/50
# 53/53 [==============================] - 242s 5s/step - loss: 347.2961 - acc: 0.6499 - val_loss: 435.4323 - val_acc: 0.6442
# Epoch 5/50
# 53/53 [==============================] - 244s 5s/step - loss: 353.3814 - acc: 0.6553 - val_loss: 419.8618 - val_acc: 0.6593
# Epoch 6/50
# 53/53 [==============================] - 249s 5s/step - loss: 349.6767 - acc: 0.6805 - val_loss: 419.6570 - val_acc: 0.6732
# Epoch 7/50
# 53/53 [==============================] - 248s 5s/step - loss: 341.1532 - acc: 0.6764 - val_loss: 462.2315 - val_acc: 0.6669
# Epoch 8/50
# ...

# %%
model.save('temp_model.h5')

# %%
# !pip uninstall keras_preprocessing
# Out:
# Uninstalling Keras-Preprocessing-1.0.9:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/Keras_Preprocessing-1.0.9.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/keras_preprocessing/*
# Proceed (y/n)? y
#   Successfully uninstalled Keras-Preprocessing-1.0.9

# %%
pip install git+https://github.com/keras-team/keras-preprocessing.git
# Out:
# ...
#   Cloning https://github.com/keras-team/keras-preprocessing.git to /tmp/pip-req-build-r791snav
#   Running command git clone -q https://github.com/keras-team/keras-preprocessing.git /tmp/pip-req-build-r791snav
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1qh0yvt_/wheels/03/a0/39/171f6040d36f36c71168dc69afa81334351b20955dc36ce932
# Successfully built Keras-Preprocessing
# ...

# %%
pip help uninstall

# %%
predictions = model.predict_generator(train_generator, STEP_SIZE_TRAIN)

predicted_classes = convert_to_class(predictions)

# %%
model.save('conv2d_human.h5')

# %%
from keras.models import load_model
loaded_model = load_model("conv2d_human.h5")

# %%
im_test=os.listdir('/content/drive/My Drive/colab_data/test/')


for j in range(1713,8560):
  
  Train_img=image.load_img('/content/drive/My Drive/colab_data/train_images/' +str(j) + '.jpeg', target_size=(32,32),grayscale=True)

# %%
im=[]
for k in range(1713,1723):
  im_test=image.load_img('/content/drive/My Drive/colab_data/train_images/' +str(k) + '.jpeg', target_size=(32,32),grayscale=True)
  im_test=image.img_to_array(im_test)
  im.append(np.array(im_test))
im_test.shape
#im_test=np.expand_dims(im_test,axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# (32, 32, 1)

# %%
import cv2

# %%
#im_test = cv2.imread('/content/drive/My Drive/colab_data/test/Copy of 0.jpeg',0)
im_test.shape
#im_test=np.expand_dims(im_test,axis=0)

# %%
im=np.array(im)
print(im.shape)
#im=np.expand_dims(im,axis=0)
#print(im.shape)
prediction = model.predict(im)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test1_generator = test_datagen.flow_from_directory(
        '/content/drive/My Drive/colab_data/test/',
        target_size=(32,32),
        batch_size=1,
        class_mode=None,
        shuffle=False)
# Out:
# Found 0 images belonging to 0 classes.

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
